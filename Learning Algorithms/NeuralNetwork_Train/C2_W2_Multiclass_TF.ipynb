# %% [markdown]
# # Optional Lab - Multi-class Classification
#
# Explore an example of multiclass classification using neural networks

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)
# Out:
# 2023-05-03 17:12:45.875891: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 2.0 Multi-class Classification
# Neural Networks are often used to classify data. Examples are neural networks:
# - take in photos and classify subjects in the photos as {dog,cat,horse,other}
# - take in a sentence and classify the 'parts of speech' of its elements: {noun, verb, adjective etc..}
#
# A network of this type will have multiple units in its final layer. Each output is associated with a category. When an input example is applied to the network, the output with the highest value is the category predicted. If the output is applied to a softmax function, the output of the softmax will provide probabilities of the input being in each category.
#
# In this lab you will see an example of building a multiclass network in Tensorflow. We will then take a look at how the neural network makes its predictions.
#
# Let's start by creating a four-class data set.

# %% [markdown]
# ## 2.1 Prepare and visualize our data
# We will use Scikit-Learn `make_blobs` function to make a training data set with 4 categories as shown in the plot below.

# %%
# make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Each dot represents a training example. The axis (x0,x1) are the inputs and the color represents the class the example is associated with. Once trained, the model will be presented with a new example, (x0,x1), and will predict the class.
#
# While generated, this data set is representative of many real-world classification problems. There are several input features (x0,...,xn) and several output categories. The model is trained to use the input features to predict the correct output category.

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")
# show how classes are represented
print(f"class representation {y_train[:10]}")
# show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %% [markdown]
# ## 2.2 Model
# <img align="Right" src="./images/C2_W2_mclass_lab_network.PNG"  style=" width:350px; padding: 10px 20px ; ">
# This lab will use a 2-layer network as shown.
# Unlike the binary classification networks, this network has four outputs, one for each class. Given an input example, the output with the highest value is the predicted class of the input.
#
# Below is an example of how to construct this network in Tensorflow. Notice the output layer uses a `linear` rather than a `softmax` activation. While it is possible to include the softmax in the output layer, it is more numerically stable if linear outputs are passed to the loss function during training. If the model is used to predict probabilities, the softmax can be applied at that point.

# %% [markdown]
# The statements below compile and train the network. Setting `from_logits=True` as an argument to the loss function specifies that the output activation was linear rather than a softmax.

# %%
tf.random.set_seed(1234)
model = Sequential(
    [
        Dense(2, activation='relu', name='L1'),
        Dense(4, activation='linear', name='L2')
    ]
)

model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(.01)
)

model.fit(
    X_train, y_train,
    epochs=200
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 1ms/step - loss: 2.9331
# Epoch 2/200
# 4/4 [==============================] - 0s 1ms/step - loss: 2.6335
# Epoch 3/200
# 4/4 [==============================] - 0s 1ms/step - loss: 2.3687
# Epoch 4/200
# 4/4 [==============================] - 0s 1ms/step - loss: 2.1443
# Epoch 5/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.9593
# Epoch 6/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.7719
# Epoch 7/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.6352
# Epoch 8/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5127
# Epoch 9/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.4188
# Epoch 10/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3241
# Epoch 11/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.2584
# Epoch 12/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.2000
# Epoch 13/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1540
# Epoch 14/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1117
# Epoch 15/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0732
# Epoch 16/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0418
# Epoch 17/200
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0123
# Epoch 18/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9850
# Epoch 19/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9606
# Epoch 20/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9384
# Epoch 21/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9171
# Epoch 22/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8955
# Epoch 23/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8762
# Epoch 24/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8581
# Epoch 25/200
# 4/4 [==============================] - 0s 965us/step - loss: 0.8395
# Epoch 26/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8231
# Epoch 27/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8052
# Epoch 28/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7881
# Epoch 29/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7723
# Epoch 30/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7580
# Epoch 31/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7427
# Epoch 32/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7290
# Epoch 33/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7135
# Epoch 34/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6978
# Epoch 35/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6835
# Epoch 36/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6689
# Epoch 37/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6542
# Epoch 38/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6380
# Epoch 39/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6173
# Epoch 40/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6005
# Epoch 41/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5821
# Epoch 42/200
# 4/4 [==============================] - 0s 991us/step - loss: 0.5654
# Epoch 43/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5481
# Epoch 44/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5295
# Epoch 45/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5126
# Epoch 46/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4973
# Epoch 47/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4804
# Epoch 48/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4649
# Epoch 49/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4491
# Epoch 50/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4341
# Epoch 51/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4188
# Epoch 52/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4033
# Epoch 53/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3884
# Epoch 54/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3748
# Epoch 55/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3600
# Epoch 56/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3461
# Epoch 57/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3326
# Epoch 58/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3199
# Epoch 59/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3082
# Epoch 60/200
# 4/4 [==============================] - 0s 978us/step - loss: 0.2969
# Epoch 61/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2861
# Epoch 62/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2759
# Epoch 63/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2663
# Epoch 64/200
# 4/4 [==============================] - 0s 869us/step - loss: 0.2569
# Epoch 65/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2492
# Epoch 66/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2394
# Epoch 67/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2309
# Epoch 68/200
# 4/4 [==============================] - 0s 944us/step - loss: 0.2234
# Epoch 69/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2163
# Epoch 70/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2098
# Epoch 71/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2036
# Epoch 72/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1981
# Epoch 73/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1922
# Epoch 74/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1869
# Epoch 75/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1816
# Epoch 76/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1768
# Epoch 77/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1723
# Epoch 78/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1673
# Epoch 79/200
# 4/4 [==============================] - 0s 924us/step - loss: 0.1626
# Epoch 80/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1580
# Epoch 81/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1541
# Epoch 82/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1504
# Epoch 83/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1469
# Epoch 84/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1434
# Epoch 85/200
# 4/4 [==============================] - 0s 989us/step - loss: 0.1401
# Epoch 86/200
# 4/4 [==============================] - 0s 971us/step - loss: 0.1369
# Epoch 87/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1333
# Epoch 88/200
# 4/4 [==============================] - 0s 877us/step - loss: 0.1303
# Epoch 89/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1269
# Epoch 90/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1242
# Epoch 91/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1215
# Epoch 92/200
# 4/4 [==============================] - 0s 955us/step - loss: 0.1189
# Epoch 93/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1166
# Epoch 94/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1141
# Epoch 95/200
# 4/4 [==============================] - 0s 998us/step - loss: 0.1117
# Epoch 96/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1096
# Epoch 97/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1074
# Epoch 98/200
# 4/4 [==============================] - 0s 822us/step - loss: 0.1055
# Epoch 99/200
# 4/4 [==============================] - 0s 943us/step - loss: 0.1038
# Epoch 100/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1018
# Epoch 101/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0999
# Epoch 102/200
# 4/4 [==============================] - 0s 989us/step - loss: 0.0982
# Epoch 103/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0965
# Epoch 104/200
# 4/4 [==============================] - 0s 994us/step - loss: 0.0948
# Epoch 105/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0927
# Epoch 106/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0911
# Epoch 107/200
# 4/4 [==============================] - 0s 987us/step - loss: 0.0894
# Epoch 108/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0876
# Epoch 109/200
# 4/4 [==============================] - 0s 843us/step - loss: 0.0858
# Epoch 110/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0845
# Epoch 111/200
# 4/4 [==============================] - 0s 815us/step - loss: 0.0831
# Epoch 112/200
# 4/4 [==============================] - 0s 867us/step - loss: 0.0819
# Epoch 113/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0805
# Epoch 114/200
# 4/4 [==============================] - 0s 939us/step - loss: 0.0793
# Epoch 115/200
# 4/4 [==============================] - 0s 886us/step - loss: 0.0780
# Epoch 116/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0769
# Epoch 117/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0757
# Epoch 118/200
# 4/4 [==============================] - 0s 950us/step - loss: 0.0746
# Epoch 119/200
# 4/4 [==============================] - 0s 911us/step - loss: 0.0735
# Epoch 120/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0727
# Epoch 121/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0716
# Epoch 122/200
# 4/4 [==============================] - 0s 887us/step - loss: 0.0707
# Epoch 123/200
# 4/4 [==============================] - 0s 891us/step - loss: 0.0695
# Epoch 124/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0686
# Epoch 125/200
# 4/4 [==============================] - 0s 983us/step - loss: 0.0676
# Epoch 126/200
# 4/4 [==============================] - 0s 994us/step - loss: 0.0666
# Epoch 127/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0657
# Epoch 128/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0649
# Epoch 129/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0640
# Epoch 130/200
# 4/4 [==============================] - 0s 978us/step - loss: 0.0629
# Epoch 131/200
# 4/4 [==============================] - 0s 973us/step - loss: 0.0625
# Epoch 132/200
# 4/4 [==============================] - 0s 865us/step - loss: 0.0616
# Epoch 133/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0609
# Epoch 134/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0600
# Epoch 135/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0593
# Epoch 136/200
# 4/4 [==============================] - 0s 831us/step - loss: 0.0584
# Epoch 137/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0577
# Epoch 138/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0569
# Epoch 139/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0562
# Epoch 140/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0555
# Epoch 141/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0547
# Epoch 142/200
# 4/4 [==============================] - 0s 943us/step - loss: 0.0540
# Epoch 143/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0534
# Epoch 144/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0528
# Epoch 145/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0522
# Epoch 146/200
# 4/4 [==============================] - 0s 987us/step - loss: 0.0515
# Epoch 147/200
# 4/4 [==============================] - 0s 876us/step - loss: 0.0510
# Epoch 148/200
# 4/4 [==============================] - 0s 955us/step - loss: 0.0505
# Epoch 149/200
# 4/4 [==============================] - 0s 975us/step - loss: 0.0499
# Epoch 150/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0495
# Epoch 151/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0492
# Epoch 152/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0487
# Epoch 153/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0482
# Epoch 154/200
# 4/4 [==============================] - 0s 973us/step - loss: 0.0476
# Epoch 155/200
# 4/4 [==============================] - 0s 894us/step - loss: 0.0470
# Epoch 156/200
# 4/4 [==============================] - 0s 890us/step - loss: 0.0463
# Epoch 157/200
# 4/4 [==============================] - 0s 874us/step - loss: 0.0458
# Epoch 158/200
# 4/4 [==============================] - 0s 978us/step - loss: 0.0452
# Epoch 159/200
# 4/4 [==============================] - 0s 930us/step - loss: 0.0448
# Epoch 160/200
# 4/4 [==============================] - 0s 969us/step - loss: 0.0444
# Epoch 161/200
# 4/4 [==============================] - 0s 984us/step - loss: 0.0437
# Epoch 162/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0432
# Epoch 163/200
# 4/4 [==============================] - 0s 961us/step - loss: 0.0427
# Epoch 164/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0423
# Epoch 165/200
# 4/4 [==============================] - 0s 905us/step - loss: 0.0419
# Epoch 166/200
# 4/4 [==============================] - 0s 974us/step - loss: 0.0414
# Epoch 167/200
# 4/4 [==============================] - 0s 986us/step - loss: 0.0411
# Epoch 168/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0406
# Epoch 169/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0402
# Epoch 170/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0398
# Epoch 171/200
# 4/4 [==============================] - 0s 959us/step - loss: 0.0394
# Epoch 172/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0390
# Epoch 173/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0387
# Epoch 174/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0383
# Epoch 175/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0379
# Epoch 176/200
# 4/4 [==============================] - 0s 868us/step - loss: 0.0375
# Epoch 177/200
# 4/4 [==============================] - 0s 911us/step - loss: 0.0372
# Epoch 178/200
# 4/4 [==============================] - 0s 918us/step - loss: 0.0368
# Epoch 179/200
# 4/4 [==============================] - 0s 888us/step - loss: 0.0367
# Epoch 180/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0361
# Epoch 181/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0358
# Epoch 182/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0356
# Epoch 183/200
# 4/4 [==============================] - 0s 982us/step - loss: 0.0353
# Epoch 184/200
# 4/4 [==============================] - 0s 936us/step - loss: 0.0350
# Epoch 185/200
# 4/4 [==============================] - 0s 888us/step - loss: 0.0346
# Epoch 186/200
# 4/4 [==============================] - 0s 932us/step - loss: 0.0342
# Epoch 187/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 188/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0336
# Epoch 189/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0333
# Epoch 190/200
# 4/4 [==============================] - 0s 980us/step - loss: 0.0331
# Epoch 191/200
# 4/4 [==============================] - 0s 855us/step - loss: 0.0329
# Epoch 192/200
# 4/4 [==============================] - 0s 939us/step - loss: 0.0327
# Epoch 193/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0323
# Epoch 194/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0320
# Epoch 195/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0317
# Epoch 196/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0314
# Epoch 197/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0311
# Epoch 198/200
# 4/4 [==============================] - 0s 898us/step - loss: 0.0308
# Epoch 199/200
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0305
# Epoch 200/200
# 4/4 [==============================] - 0s 903us/step - loss: 0.0302

# %% [markdown]
# With the model trained, we can see how the model has classified the training data.

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 184/184 [==============================] - 0s 433us/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Above, the decision boundaries show how the model has partitioned the input space.  This very simple model has had no trouble classifying the training data. How did it accomplish this? Let's look at the network in more detail.
#
# Below, we will pull the trained weights from the model and use that to plot the function of each of the network units. Further down, there is a more detailed explanation of the results. You don't need to know these details to successfully use neural networks, but it may be helpful to gain more intuition about how the layers combine to solve a classification problem.

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1")
W1,b1 = l1.get_weights()

# %%
# plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()
# create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1)

plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# #### Layer 2, the output layer  <img align="Right" src="./images/C2_W2_mclass_layer2.png"  style=" width:600px; padding: 10px 20px ; ">
#
# The dots in these graphs are the training examples translated by the first layer. One way to think of this is the first layer has created a new set of features for evaluation by the 2nd layer. The axes in these plots are the outputs of the previous layer $a^{[1]}_0$ and $a^{[1]}_1$. As predicted above, classes 0 and 1 (blue and green) have  $a^{[1]}_0 = 0$ while classes 0 and 2 (blue and orange) have $a^{[1]}_1 = 0$.
# Once again, the intensity of the background color indicates the highest values.
# Unit 0 will produce its maximum value for values near (0,0), where class 0 (blue) has been mapped.
# Unit 1 produces its highest values in the upper left corner selecting class 1 (green).
# Unit 2 targets the lower right corner where class 2 (orange) resides.
# Unit 3 produces its highest values in the upper right selecting our final class (purple).
#
# One other aspect that is not obvious from the graphs is that the values have been coordinated between the units. It is not sufficient for a unit to produce a maximum value for the class it is selecting for, it must also be the highest value of all the units for points in that class. This is done by the implied softmax function that is part of the loss function (`SparseCategoricalCrossEntropy`). Unlike other activation functions, the softmax works across all the outputs.
#
# You can successfully use neural networks without knowing the details of what each unit is up to. Hopefully, this example has provided some intuition about what is happening under the hood.
